# %% [markdown]
# # Spacy

# %%
import spacy
nlp = spacy.load('en_core_web_sm')    #load the language model instance

# %% [markdown]
# Spacy to create a processed Doc object, which is a container for accessing linguistic annotations, for a given input string

# %%
introduction_text = ('This space is about Natural'     
                     ' Language Processing in Spacy.')
introduction_doc = nlp(introduction_text)
#Extract tokens for the given doc
print([token.text for token in introduction_doc])
# Out:
# ['This', 'space', 'is', 'about', 'Natural', 'Language', 'Processing', 'in', 'Spacy', '.']

# %%
about_text = ('Apple Inc. is an American multinational technology company headquartered in Cupertino, California, '
            'that designs, develops, and sells consumer electronics, computer software, and online services. '
            'It is considered one of the Big Four technology companies, alongside Amazon, Google, and Microsoft. '
            'It was founded by Steve Jobs, Steve Wozniak, and Ronald Wayne in April 1976')

# %% [markdown]
# Sentence Detection is the process of locating the start and end of sentences in a given text

# %%
about_doc = nlp(about_text)
sentences = list(about_doc.sents)
for sentence in sentences:
    print(sentence)
len(sentences)
# Out:
# Apple Inc. is an American multinational technology company headquartered in Cupertino, California, that designs, develops, and sells consumer electronics, computer software, and online services.
# It is considered one of the Big Four technology companies, alongside Amazon, Google, and Microsoft.
# It was founded by Steve Jobs, Steve Wozniak, and Ronald Wayne in April 1976
# 3

# %%
token_dict={}
for token in about_doc:
    token_dict[token]=token.idx       #spacy preseverves the starting-index of each token which is helpful for in-place replacement
token_dict
# Out:
# {Apple: 0,
#  Inc.: 6,
#  is: 11,
#  an: 14,
#  American: 17,
#  multinational: 26,
#  technology: 40,
#  company: 51,
#  headquartered: 59,
#  in: 73,
#  Cupertino: 76,
#  ,: 85,
#  California: 87,
#  ,: 97,
#  that: 99,
#  designs: 104,
#  ,: 111,
#  develops: 113,
#  ,: 121,
#  and: 123,
#  sells: 127,
#  consumer: 133,
#  electronics: 142,
#  ,: 153,
#  computer: 155,
#  software: 164,
#  ,: 172,
#  and: 174,
#  online: 178,
#  services: 185,
#  .: 193,
#  It: 195,
#  is: 198,
#  considered: 201,
#  one: 212,
#  of: 216,
#  the: 219,
#  Big: 223,
#  Four: 227,
#  technology: 232,
#  companies: 243,
#  ,: 252,
#  alongside: 254,
#  Amazon: 264,
#  ,: 270,
#  Google: 272,
#  ,: 278,
#  and: 280,
#  Microsoft: 284,
#  .: 293,
#  It: 295,
#  was: 298,
#  founded: 302,
#  by: 310,
#  Steve: 313,
#  Jobs: 319,
#  ,: 323,
#  Steve: 325,
#  Wozniak: 331,
#  ,: 338,
#  and: 340,
#  Ronald: 344,
#  Wayne: 351,
#  in: 357,
#  April: 360,
#  1976: 366}

# %%
for token in about_doc:
    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
            token.shape_, token.is_alpha, token.is_stop,spacy.explain(token.tag_))
# Out:
# Apple Apple PROPN NNP compound Xxxxx True False noun, proper singular
# Inc. Inc. PROPN NNP nsubj Xxx. False False noun, proper singular
# is be AUX VBZ ROOT xx True True verb, 3rd person singular present
# an an DET DT det xx True True determiner
# American american ADJ JJ amod Xxxxx True False adjective
# multinational multinational ADJ JJ amod xxxx True False adjective
# technology technology NOUN NN compound xxxx True False noun, singular or mass
# company company NOUN NN attr xxxx True False noun, singular or mass
# headquartered headquarter VERB VBN acl xxxx True False verb, past participle
# in in ADP IN prep xx True True conjunction, subordinating or preposition
# Cupertino Cupertino PROPN NNP pobj Xxxxx True False noun, proper singular
# , , PUNCT , punct , False False punctuation mark, comma
# California California PROPN NNP appos Xxxxx True False noun, proper singular
# , , PUNCT , punct , False False punctuation mark, comma
# that that SCONJ IN det xxxx True True conjunction, subordinating or preposition
# designs design NOUN NNS relcl xxxx True False noun, plural
# , , PUNCT , punct , False False punctuation mark, comma
# develops develop VERB VBZ conj xxxx True False verb, 3rd person singular present
# , , PUNCT , punct , False False punctuation mark, comma
# and and CCONJ CC cc xxx True True conjunction, coordinating
# sells sell VERB VBZ conj xxxx True False verb, 3rd person singular present
# consumer consumer NOUN NN compound xxxx True False noun, singular or mass
# electronics electronic NOUN NNS dobj xxxx True False noun, plural
# , , PUNCT , punct , False False punctuation mark, comma
# computer computer NOUN NN compound xxxx True False noun, singular or mass
# software software NOUN NN conj xxxx True False noun, singular or mass
# , , PUNCT , punct , False False punctuation mark, comma
# and and CCONJ CC cc xxx True True conjunction, coordinating
# online online ADJ JJ amod xxxx True False adjective
# services service NOUN NNS conj xxxx True False noun, plural
# . . PUNCT . punct . False False punctuation mark, sentence closer
# It -PRON- PRON PRP nsubjpass Xx True True pronoun, personal
# is be AUX VBZ auxpass xx True True verb, 3rd person singular present
# considered consider VERB VBN ROOT xxxx True False verb, past participle
# one one NUM CD oprd xxx True True cardinal number
# of of ADP IN prep xx True True conjunction, subordinating or preposition
# the the DET DT det xxx True True determiner
# Big Big PROPN NNP compound Xxx True False noun, proper singular
# Four Four PROPN NNP compound Xxxx True True noun, proper singular
# technology technology NOUN NN compound xxxx True False noun, singular or mass
# companies company NOUN NNS pobj xxxx True False noun, plural
# , , PUNCT , punct , False False punctuation mark, comma
# alongside alongside ADP IN prep xxxx True False conjunction, subordinating or preposition
# Amazon Amazon PROPN NNP pobj Xxxxx True False noun, proper singular
# , , PUNCT , punct , False False punctuation mark, comma
# Google Google PROPN NNP conj Xxxxx True False noun, proper singular
# , , PUNCT , punct , False False punctuation mark, comma
# and and CCONJ CC cc xxx True True conjunction, coordinating
# Microsoft Microsoft PROPN NNP conj Xxxxx True False noun, proper singular
# . . PUNCT . punct . False False punctuation mark, sentence closer
# It -PRON- PRON PRP nsubjpass Xx True True pronoun, personal
# was be AUX VBD auxpass xxx True True verb, past tense
# founded found VERB VBN ROOT xxxx True False verb, past participle
# by by ADP IN agent xx True True conjunction, subordinating or preposition
# Steve Steve PROPN NNP compound Xxxxx True False noun, proper singular
# Jobs Jobs PROPN NNP pobj Xxxx True False noun, proper singular
# , , PUNCT , punct , False False punctuation mark, comma
# Steve Steve PROPN NNP compound Xxxxx True False noun, proper singular
# Wozniak Wozniak PROPN NNP conj Xxxxx True False noun, proper singular
# , , PUNCT , punct , False False punctuation mark, comma
# and and CCONJ CC cc xxx True True conjunction, coordinating
# Ronald Ronald PROPN NNP compound Xxxxx True False noun, proper singular
# Wayne Wayne PROPN NNP conj Xxxxx True False noun, proper singular
# in in ADP IN prep xx True True conjunction, subordinating or preposition
# April April PROPN NNP pobj Xxxxx True False noun, proper singular
# 1976 1976 NUM CD nummod dddd False False cardinal number

# %%
from collections import Counter
words = [token.text for token in about_doc
          if not token.is_stop and not token.is_punct]
word_freq = Counter(words)
common_words = word_freq.most_common(5)   #5 common words and their freq
print(common_words)
unique_words = [word for (word, freq) in word_freq.items() if freq == 1]
print(unique_words)
# Out:
# [('technology', 2), ('Steve', 2), ('Apple', 1), ('Inc.', 1), ('American', 1)]
# ['Apple', 'Inc.', 'American', 'multinational', 'company', 'headquartered', 'Cupertino', 'California', 'designs', 'develops', 'sells', 'consumer', 'electronics', 'computer', 'software', 'online', 'services', 'considered', 'Big', 'companies', 'alongside', 'Amazon', 'Google', 'Microsoft', 'founded', 'Jobs', 'Wozniak', 'Ronald', 'Wayne', 'April', '1976']

# %%
from spacy import displacy
displacy.serve(about_doc, style='dep')
# Out:
# C:\Users\tubaa\Anaconda3\lib\runpy.py:193: UserWarning: [W011] It looks like you're calling displacy.serve from within a Jupyter notebook or a similar environment. This likely means you're already running a local web server, so there's no need to make displaCy start another one. Instead, you should be able to replace displacy.serve with displacy.render to show the visualization.
#   "__main__", mod_spec)
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="b45cef6ac89f432f83a69a52fcfb0b53-0" class="displacy" width="9325" height="837.0" direction="ltr" style="max-width: none; height: 837.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Apple</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">Inc.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">an</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">American</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">multinational</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">technology</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">company</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">headquartered</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">Cupertino,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">California,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">designs,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">develops,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">sells</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">consumer</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">electronics,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">computer</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">software,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">online</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">services.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">It</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">considered</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">one</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="m
# Using the 'dep' visualizer
# Serving on http://0.0.0.0:5000 ...
# 127.0.0.1 - - [31/May/2020 00:40:10] "GET / HTTP/1.1" 200 43443
# 127.0.0.1 - - [31/May/2020 00:40:12] "GET /favicon.ico HTTP/1.1" 200 43443
# Shutting down server on port 5000.

# %% [markdown]
# Dependency parsing is the process of extracting the dependency parse of a sentence to represent its grammatical structure. It defines the dependency relationship between headwords and their dependents.
# Graphically - Words are the NODES and grammatical relationship are the EDGES

# %%
plain_text = 'Tuba is learning Python'
plain_doc = nlp(plain_text)
for token in plain_doc:
    print (token.text, token.tag_, token.head.text, token.dep_)
# Out:
# Tuba NNP learning nsubj
# is VBZ learning aux
# learning VBG learning ROOT
# Python NNP learning dobj

# %%
displacy.serve(plain_doc, style='dep')
# Out:
# C:\Users\tubaa\Anaconda3\lib\runpy.py:193: UserWarning: [W011] It looks like you're calling displacy.serve from within a Jupyter notebook or a similar environment. This likely means you're already running a local web server, so there's no need to make displaCy start another one. Instead, you should be able to replace displacy.serve with displacy.render to show the visualization.
#   "__main__", mod_spec)
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="79d86319b16f4004bc13f8d20eeba900-0" class="displacy" width="750" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Tuba</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">learning</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">Python</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-79d86319b16f4004bc13f8d20eeba900-0-0" stroke-width="2px" d="M70,177.0 C70,2.0 400.0,2.0 400.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-79d86319b16f4004bc13f8d20eeba900-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,179.0 L62,167.0 78,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-79d86319b16f4004bc13f8d20eeba900-0-1" stroke-width="2px" d="M245,177.0 C245,89.5 395.0,89.5 395.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-79d86319b16f4004bc13f8d20eeba900-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,179.0 L237,167.0 253,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-79d86319b16f4004bc13f8d20eeba900-0-2" stroke-width="2px" d="M420,177.0 C420,89.5 570.0,89.5 570.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-79d86319b16f4004bc13f8d20eeba900-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M570.0,179.0 L578.0,167.0 562.0,167.0" fill="currentColor"/>
# </g>
# </svg>
# </figure>
# </body>
# </html></span>
# Using the 'dep' visualizer
# Serving on http://0.0.0.0:5000 ...

# %% [markdown]
# Shallow parsing, or chunking, is the process of extracting phrases from unstructured text. Chunking groups adjacent tokens into phrases on the basis of their POS tags. There are some standard well-known chunks such as noun phrases, verb phrases, and prepositional phrases.

# %%
for chunk in about_doc.noun_chunks:
    print(chunk)
# Out:
# Apple Inc.
# an American multinational technology company
# Cupertino
# California
# consumer electronics
# computer software
# online services
# It
# the Big Four technology companies
# Amazon
# Google
# Microsoft
# It
# Steve Jobs
# Steve Wozniak
# Ronald Wayne
# April

# %%
conference_text = ('There is a developer conference happening on 21 July 2019 in London.')
conference_doc = nlp(conference_text)
for chunk in conference_doc.noun_chunks:
    print(chunk)
# Out:
# a developer conference
# 21 July
# London

# %% [markdown]
# Entity Recognition

# %%
ent_text = ('Apple is looking at buying U.K. startup for $1 billion')
ent_doc = nlp(ent_text)
for ent in ent_doc.ents:
     print(ent.text, ent.start_char, ent.end_char,
           ent.label_, spacy.explain(ent.label_))
# Out:
# Apple 0 5 ORG Companies, agencies, institutions, etc.
# U.K. 27 31 GPE Countries, cities, states
# $1 billion 44 54 MONEY Monetary values, including unit
